# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
#   File "<ipython-input-1-35d08d0c3ade>", line 2
#     drive.mount('/content/drive'
#                                 ^
# SyntaxError: incomplete input
