# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
#   File "<ipython-input-1-35d08d0c3ade>", line 2
#     drive.mount('/content/drive'
#                                 ^
# SyntaxError: incomplete input

# %%
Hello world
# Out:
#   File "<ipython-input-1-33ab5639bfd8>", line 1
#     Hello world
#           ^
# SyntaxError: invalid syntax
